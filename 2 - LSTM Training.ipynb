# %%
import numpy as np

data=np.load('data.npy')
target=np.load('target.npy')

# %%
train_data=data[:2500]
train_target=target[:2500]

test_data=data[2500:]
test_target=target[2500:]

print(train_data.shape)
print(test_data.shape)
print(train_target.shape)
print(test_target.shape)
# Out:
# (2500, 50, 1)
# (689, 50, 1)
# (2500, 1)
# (689, 1)

# %%
from matplotlib import pyplot as plt

plt.plot(train_target,'r',label='target')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Open Value/$')
plt.show()

# %%
from matplotlib import pyplot as plt

test_x_range=np.arange(2500,3189,1)
#test_x_range is an array of values between 1000-1208

plt.plot(train_target,'r',label='train')
plt.plot(test_x_range,test_target,'b',label='test')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Open Value/$')
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

model=Sequential()

model.add(LSTM(units=96,return_sequences=True,input_shape=(50,1)))
model.add(Dropout(0.2))

model.add(LSTM(units=96,return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=96,return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=40,return_sequences=False))
model.add(Dropout(0.2))

model.add(Dense(1,activation='linear'))

model.compile(loss='mse',optimizer='adam')
# Out:
# c:\Users\USER\Music\DeepL\myenvdeep\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
history=model.fit(train_data,train_target,epochs=50,validation_data=(test_data,test_target))
# Out:
# Epoch 1/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - loss: 0.0097 - val_loss: 0.0036
# Epoch 2/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0011 - val_loss: 0.0035
# Epoch 3/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 9.6983e-04 - val_loss: 0.0033
# Epoch 4/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 8.7608e-04 - val_loss: 0.0030
# Epoch 5/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 8.0904e-04 - val_loss: 0.0029
# Epoch 6/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 7.8845e-04 - val_loss: 0.0037
# Epoch 7/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 6.8730e-04 - val_loss: 0.0027
# Epoch 8/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 6.0932e-04 - val_loss: 0.0029
# Epoch 9/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 6.5625e-04 - val_loss: 0.0027
# Epoch 10/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 6.8570e-04 - val_loss: 0.0028
# Epoch 11/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 7.1473e-04 - val_loss: 0.0027
# Epoch 12/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 4.9562e-04 - val_loss: 0.0026
# Epoch 13/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 4.8724e-04 - val_loss: 0.0025
# Epoch 14/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 4.8506e-04 - val_loss: 0.0023
# Epoch 15/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 4.2510e-04 - val_loss: 0.0023
# Epoch 16/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 9s 119ms/step - loss: 4.2817e-04 - val_loss: 0.0026
# Epoch 17/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - loss: 4.8834e-04 - val_loss: 0.0028
# Epoch 18/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 9s 117ms/step - loss: 4.2339e-04 - val_loss: 0.0027
# Epoch 19/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - loss: 4.1264e-04 - val_loss: 0.0029
# Epoch 20/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 9s 108ms/step - loss: 4.6206e-04 - val_loss: 0.0024
# Epoch 21/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 8s 105ms/step - loss: 4.3575e-04 - val_loss: 0.0021
# Epoch 22/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - loss: 4.0967e-04 - val_loss: 0.0019
# Epoch 23/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 4.1792e-04 - val_loss: 0.0020
# Epoch 24/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 3.5404e-04 - val_loss: 0.0018
# Epoch 25/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 3.4447e-04 - val_loss: 0.0018
# Epoch 26/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 3.5055e-04 - val_loss: 0.0021
# Epoch 27/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 3.3535e-04 - val_loss: 0.0016
# Epoch 28/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 3.4154e-04 - val_loss: 0.0018
# Epoch 29/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 3.5433e-04 - val_loss: 0.0016
# Epoch 30/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 3.1153e-04 - val_loss: 0.0015
# Epoch 31/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 3.8119e-04 - val_loss: 0.0015
# Epoch 32/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 3.1856e-04 - val_loss: 0.0016
# Epoch 33/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 5.0258e-04 - val_loss: 0.0017
# Epoch 34/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 2.8267e-04 - val_loss: 0.0014
# Epoch 35/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 3.1133e-04 - val_loss: 0.0016
# Epoch 36/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 2.8741e-04 - val_loss: 0.0013
# Epoch 37/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - loss: 2.9969e-04 - val_loss: 0.0013
# Epoch 38/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 2.6681e-04 - val_loss: 0.0013
# Epoch 39/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 3.2124e-04 - val_loss: 0.0012
# Epoch 40/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 2.8707e-04 - val_loss: 0.0016
# Epoch 41/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 3.5868e-04 - val_loss: 0.0014
# Epoch 42/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - loss: 2.8333e-04 - val_loss: 0.0011
# Epoch 43/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 2.7210e-04 - val_loss: 0.0011
# Epoch 44/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 3.0343e-04 - val_loss: 0.0012
# Epoch 45/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 2.7518e-04 - val_loss: 0.0011
# Epoch 46/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 3.2201e-04 - val_loss: 0.0011
# Epoch 47/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 2.7034e-04 - val_loss: 0.0011
# Epoch 48/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 2.7169e-04 - val_loss: 0.0010
# Epoch 49/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 2.8420e-04 - val_loss: 0.0013
# Epoch 50/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 3.0175e-04 - val_loss: 0.0010

# %%
plt.plot(history.history['loss'],'r',label='train loss')
plt.plot(history.history['val_loss'],'g',label='val loss')
plt.xlabel('# epoch')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
result=model.predict(test_data)

from sklearn.metrics import r2_score

r2=r2_score(test_target,result)
print('r2 score:',r2)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# r2 score: 0.9652487053180732

# %%
test_x_range=np.arange(2500,3189,1)
#test_x_range is an array of values between 1000-1208

plt.plot(train_target,'r',label='train')
plt.plot(test_x_range,test_target,'b',label='test')
plt.plot(test_x_range,result,'g',label='predicted')

plt.xlabel('Date')
plt.ylabel('Open Value/$')
plt.legend()
plt.show()

# %%
plt.plot(test_target,'b',label='test')
plt.plot(result,'g',label='predicted')

plt.xlabel('Date')
plt.ylabel('Open Value/$')
plt.legend()
plt.show()

# %%
model.save('LSTM-Stock-Market.keras')

# %% [markdown]
# After Analyzing

# %%
result=model.predict(test_data)

from sklearn.metrics import r2_score

r2=r2_score(test_target,result+0.03)
print('r2 score:',r2)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# r2 score: 0.9036884659311237

# %%
plt.plot(test_target,'b',label='test')
plt.plot(result+0.03,'g',label='predicted')

plt.xlabel('Date')
plt.ylabel('Open Value/$')
plt.legend()
plt.show()
